# %% [markdown]
# <a href="https://colab.research.google.com/github/k-sahaj/DS-projects/blob/main/Diabetes_prediction/Diabetes_prediction_using_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **AN ML PROJECT FOR DIABETES PREDICTION**
